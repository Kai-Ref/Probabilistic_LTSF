# %%
import numpy as np

from scoringrules.visualization import reliability_diagram

x = np.random.uniform(0, 1, 1024)

y = np.random.binomial(1, np.sqrt(x), 1024)

ax = reliability_diagram(y, x, uncertainty_band='confidence', n_bootstrap=1000, alpha=0.05)

# %%
from utils.reliability_diagram import reliability_diagram

ax = reliability_diagram(y, x, uncertainty_band='confidence', n_bootstrap=1000, alpha=0.05)

# %%
# !pip install scoringrules
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached scoringrules-0.7.1-py3-none-any.whl.metadata (16 kB)
# ...
# Using cached scoringrules-0.7.1-py3-none-any.whl (73 kB)
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
